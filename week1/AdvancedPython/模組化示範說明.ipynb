# %%
# !git clone https://github.com/oreilly-japan/deep-learning-from-scratch.git
# Out:
# Cloning into 'deep-learning-from-scratch'...
# remote: Enumerating objects: 446, done.
# remote: Total 446 (delta 0), reused 0 (delta 0), pack-reused 446
# Receiving objects: 100% (446/446), 5.51 MiB | 4.28 MiB/s, done.
# Resolving deltas: 100% (233/233), done.

# %%
ls
# Out:
# deep-learning-from-scratch/  sample_data/

# %%
cd deep-learning-from-scratch
# Out:
# /content/deep-learning-from-scratch

# %%
ls
# Out:
# ch01/  ch03/  ch05/  ch07/  common/   LICENSE.md*
# ch02/  ch04/  ch06/  ch08/  dataset/  README.md

# %%
cd ch06/
# Out:
# /content/deep-learning-from-scratch/ch06

# %%
ls
# Out:
# batch_norm_gradient_check.py    overfit_dropout.py
# batch_norm_test.py              overfit_weight_decay.py
# hyperparameter_optimization.py  weight_init_activation_histogram.py
# optimizer_compare_mnist.py      weight_init_compare.py
# optimizer_compare_naive.py

# %%
# !python batch_norm_test.py
# Out:
# Downloading train-images-idx3-ubyte.gz ...
# Done
# Downloading train-labels-idx1-ubyte.gz ...
# Done
# Downloading t10k-images-idx3-ubyte.gz ...
# Done
# Downloading t10k-labels-idx1-ubyte.gz ...
# Done
# Converting train-images-idx3-ubyte.gz to NumPy Array ...
# Done
# Converting train-labels-idx1-ubyte.gz to NumPy Array ...
# Done
# Converting t10k-images-idx3-ubyte.gz to NumPy Array ...
# Done
# Converting t10k-labels-idx1-ubyte.gz to NumPy Array ...
# Done
# Creating pickle file ...
# Done!
# ============== 1/16 ==============
# epoch:0 | 0.094 - 0.088
# ../common/functions.py:32: RuntimeWarning: invalid value encountered in subtract
#   x = x - np.max(x, axis=-1, keepdims=True)   # オーバーフロー対策
# ../common/layers.py:12: RuntimeWarning: invalid value encountered in less_equal
#   self.mask = (x <= 0)
# epoch:1 | 0.097 - 0.121
# epoch:2 | 0.097 - 0.182
# epoch:3 | 0.097 - 0.203
# epoch:4 | 0.097 - 0.235
# epoch:5 | 0.097 - 0.254
# epoch:6 | 0.097 - 0.27
# epoch:7 | 0.097 - 0.293
# epoch:8 | 0.097 - 0.308
# epoch:9 | 0.097 - 0.336
# epoch:10 | 0.097 - 0.34
# epoch:11 | 0.097 - 0.355
# epoch:12 | 0.097 - 0.364
# epoch:13 | 0.097 - 0.389
# epoch:14 | 0.097 - 0.394
# epoch:15 | 0.097 - 0.41
# epoch:16 | 0.097 - 0.416
# epoch:17 | 0.097 - 0.428
# epoch:18 | 0.097 - 0.441
# epoch:19 | 0.097 - 0.44
# No handles with labels found to put in legend.
# ============== 2/16 ==============
# epoch:0 | 0.105 - 0.107
# ../common/functions.py:32: RuntimeWarning: invalid value encountered in subtract
#   x = x - np.max(x, axis=-1, keepdims=True)   # オーバーフロー対策
# ../common/layers.py:12: RuntimeWarning: invalid value encountered in less_equal
#   self.mask = (x <= 0)
# epoch:1 | 0.097 - 0.101
# epoch:2 | 0.097 - 0.123
# epoch:3 | 0.097 - 0.168
# epoch:4 | 0.097 - 0.206
# epoch:5 | 0.097 - 0.232
# epoch:6 | 0.097 - 0.245
# epoch:7 | 0.097 - 0.272
# epoch:8 | 0.097 - 0.288
# epoch:9 | 0.097 - 0.31
# epoch:10 | 0.097 - 0.331
# epoch:11 | 0.097 - 0.356
# epoch:12 | 0.097 - 0.364
# epoch:13 | 0.097 - 0.382
# epoch:14 | 0.097 - 0.395
# epoch:15 | 0.097 - 0.424
# epoch:16 | 0.097 - 0.438
# epoch:17 | 0.097 - 0.459
# epoch:18 | 0.097 - 0.466
# epoch:19 | 0.097 - 0.483
# No handles with labels found to put in legend.
# ============== 3/16 ==============
# epoch:0 | 0.102 - 0.105
# epoch:1 | 0.378 - 0.104
# epoch:2 | 0.537 - 0.128
# epoch:3 | 0.617 - 0.171
# epoch:4 | 0.687 - 0.194
# epoch:5 | 0.736 - 0.223
# epoch:6 | 0.78 - 0.259
# epoch:7 | 0.809 - 0.303
# epoch:8 | 0.842 - 0.331
# epoch:9 | 0.867 - 0.355
# epoch:10 | 0.891 - 0.393
# epoch:11 | 0.907 - 0.422
# epoch:12 | 0.92 - 0.459
# epoch:13 | 0.941 - 0.485
# epoch:14 | 0.951 - 0.503
# epoch:15 | 0.96 - 0.522
# epoch:16 | 0.964 - 0.543
# epoch:17 | 0.969 - 0.562
# epoch:18 | 0.978 - 0.58
# epoch:19 | 0.981 - 0.605
# No handles with labels found to put in legend.
# ============== 4/16 ==============
# epoch:0 | 0.119 - 0.113
# epoch:1 | 0.323 - 0.13
# epoch:2 | 0.439 - 0.204
# epoch:3 | 0.537 - 0.261
# epoch:4 | 0.611 - 0.319
# epoch:5 | 0.651 - 0.363
# epoch:6 | 0.695 - 0.426
# epoch:7 | 0.723 - 0.474
# epoch:8 | 0.755 - 0.523
# epoch:9 | 0.773 - 0.549
# epoch:10 | 0.801 - 0.58
# epoch:11 | 0.797 - 0.594
# epoch:12 | 0.823 - 0.63
# epoch:13 | 0.83 - 0.651
# epoch:14 | 0.847 - 0.685
# epoch:15 | 0.859 - 0.701
# epoch:16 | 0.87 - 0.718
# epoch:17 | 0.869 - 0.743
# epoch:18 | 0.882 - 0.753
# epoch:19 | 0.891 - 0.766
# No handles with labels found to put in legend.
# ============== 5/16 ==============
# epoch:0 | 0.109 - 0.068
# epoch:1 | 0.107 - 0.099
# epoch:2 | 0.112 - 0.199
# epoch:3 | 0.114 - 0.334
# epoch:4 | 0.12 - 0.492
# epoch:5 | 0.127 - 0.571
# epoch:6 | 0.141 - 0.634
# epoch:7 | 0.147 - 0.669
# epoch:8 | 0.152 - 0.711
# epoch:9 | 0.178 - 0.741
# epoch:10 | 0.204 - 0.76
# epoch:11 | 0.231 - 0.786
# epoch:12 | 0.257 - 0.8
# epoch:13 | 0.273 - 0.816
# epoch:14 | 0.298 - 0.831
# epoch:15 | 0.306 - 0.844
# epoch:16 | 0.314 - 0.859
# epoch:17 | 0.309 - 0.871
# epoch:18 | 0.297 - 0.877
# epoch:19 | 0.295 - 0.886
# No handles with labels found to put in legend.
# ============== 6/16 ==============
# epoch:0 | 0.107 - 0.097
# epoch:1 | 0.118 - 0.128
# epoch:2 | 0.123 - 0.364
# epoch:3 | 0.12 - 0.553
# epoch:4 | 0.117 - 0.652
# epoch:5 | 0.123 - 0.715
# epoch:6 | 0.12 - 0.761
# epoch:7 | 0.128 - 0.795
# epoch:8 | 0.172 - 0.807
# epoch:9 | 0.12 - 0.824
# epoch:10 | 0.125 - 0.839
# epoch:11 | 0.117 - 0.856
# epoch:12 | 0.117 - 0.874
# epoch:13 | 0.117 - 0.89
# epoch:14 | 0.117 - 0.899
# epoch:15 | 0.121 - 0.909
# epoch:16 | 0.177 - 0.921
# epoch:17 | 0.138 - 0.93
# epoch:18 | 0.152 - 0.932
# epoch:19 | 0.195 - 0.933
# No handles with labels found to put in legend.
# ============== 7/16 ==============
# epoch:0 | 0.14 - 0.104
# epoch:1 | 0.117 - 0.272
# epoch:2 | 0.117 - 0.613
# epoch:3 | 0.117 - 0.701
# epoch:4 | 0.117 - 0.732
# epoch:5 | 0.117 - 0.769
# epoch:6 | 0.117 - 0.802
# epoch:7 | 0.117 - 0.832
# epoch:8 | 0.116 - 0.873
# epoch:9 | 0.116 - 0.898
# epoch:10 | 0.116 - 0.916
# epoch:11 | 0.116 - 0.932
# epoch:12 | 0.116 - 0.947
# epoch:13 | 0.116 - 0.955
# epoch:14 | 0.116 - 0.962
# epoch:15 | 0.116 - 0.97
# epoch:16 | 0.116 - 0.977
# epoch:17 | 0.116 - 0.982
# epoch:18 | 0.116 - 0.985
# epoch:19 | 0.116 - 0.989
# No handles with labels found to put in legend.
# ============== 8/16 ==============
# epoch:0 | 0.116 - 0.122
# epoch:1 | 0.117 - 0.473
# epoch:2 | 0.116 - 0.685
# epoch:3 | 0.116 - 0.753
# epoch:4 | 0.116 - 0.789
# epoch:5 | 0.116 - 0.822
# epoch:6 | 0.117 - 0.85
# epoch:7 | 0.117 - 0.871
# epoch:8 | 0.117 - 0.897
# epoch:9 | 0.116 - 0.91
# epoch:10 | 0.116 - 0.953
# epoch:11 | 0.117 - 0.971
# epoch:12 | 0.116 - 0.987
# epoch:13 | 0.116 - 0.988
# epoch:14 | 0.116 - 0.99
# epoch:15 | 0.116 - 0.993
# epoch:16 | 0.116 - 0.994
# epoch:17 | 0.116 - 0.996
# epoch:18 | 0.116 - 0.997
# epoch:19 | 0.117 - 0.997
# No handles with labels found to put in legend.
# ============== 9/16 ==============
# epoch:0 | 0.1 - 0.099
# epoch:1 | 0.117 - 0.514
# epoch:2 | 0.117 - 0.776
# epoch:3 | 0.117 - 0.833
# epoch:4 | 0.117 - 0.851
# epoch:5 | 0.117 - 0.873
# epoch:6 | 0.117 - 0.879
# epoch:7 | 0.117 - 0.891
# epoch:8 | 0.117 - 0.896
# epoch:9 | 0.117 - 0.9
# epoch:10 | 0.117 - 0.903
# epoch:11 | 0.117 - 0.915
# epoch:12 | 0.117 - 0.985
# epoch:13 | 0.116 - 0.998
# epoch:14 | 0.117 - 0.999
# epoch:15 | 0.116 - 0.999
# epoch:16 | 0.117 - 0.999
# epoch:17 | 0.116 - 0.999
# epoch:18 | 0.116 - 0.999
# epoch:19 | 0.116 - 0.999
# No handles with labels found to put in legend.
# ============== 10/16 ==============
# epoch:0 | 0.1 - 0.125
# epoch:1 | 0.116 - 0.639
# epoch:2 | 0.116 - 0.738
# epoch:3 | 0.117 - 0.779
# epoch:4 | 0.116 - 0.791
# epoch:5 | 0.116 - 0.808
# epoch:6 | 0.116 - 0.866
# epoch:7 | 0.116 - 0.895
# epoch:8 | 0.116 - 0.945
# epoch:9 | 0.117 - 0.938
# epoch:10 | 0.117 - 0.989
# epoch:11 | 0.116 - 0.981
# epoch:12 | 0.116 - 0.993
# epoch:13 | 0.116 - 0.993
# epoch:14 | 0.116 - 0.995
# epoch:15 | 0.117 - 0.996
# epoch:16 | 0.117 - 0.997
# epoch:17 | 0.117 - 0.998
# epoch:18 | 0.117 - 0.997
# epoch:19 | 0.117 - 0.998
# No handles with labels found to put in legend.
# ============== 11/16 ==============
# epoch:0 | 0.105 - 0.1
# epoch:1 | 0.116 - 0.557
# epoch:2 | 0.116 - 0.838
# epoch:3 | 0.117 - 0.779
# epoch:4 | 0.117 - 0.89
# epoch:5 | 0.116 - 0.928
# epoch:6 | 0.116 - 0.909
# epoch:7 | 0.116 - 0.965
# epoch:8 | 0.116 - 0.959
# epoch:9 | 0.116 - 0.969
# epoch:10 | 0.116 - 0.981
# epoch:11 | 0.116 - 0.99
# epoch:12 | 0.116 - 0.97
# epoch:13 | 0.116 - 0.986
# epoch:14 | 0.116 - 0.994
# epoch:15 | 0.117 - 0.994
# epoch:16 | 0.116 - 0.959
# epoch:17 | 0.116 - 0.986
# epoch:18 | 0.116 - 0.992
# epoch:19 | 0.116 - 0.995
# No handles with labels found to put in legend.
# ============== 12/16 ==============
# epoch:0 | 0.117 - 0.215
# epoch:1 | 0.117 - 0.518
# epoch:2 | 0.117 - 0.406
# epoch:3 | 0.117 - 0.733
# epoch:4 | 0.117 - 0.734
# epoch:5 | 0.117 - 0.778
# epoch:6 | 0.117 - 0.787
# epoch:7 | 0.117 - 0.789
# epoch:8 | 0.117 - 0.795
# epoch:9 | 0.117 - 0.796
# epoch:10 | 0.117 - 0.8
# epoch:11 | 0.117 - 0.803
# epoch:12 | 0.117 - 0.82
# epoch:13 | 0.117 - 0.805
# epoch:14 | 0.117 - 0.802
# epoch:15 | 0.117 - 0.811
# epoch:16 | 0.117 - 0.885
# epoch:17 | 0.117 - 0.895
# epoch:18 | 0.117 - 0.897
# epoch:19 | 0.117 - 0.898
# No handles with labels found to put in legend.
# ============== 13/16 ==============
# epoch:0 | 0.117 - 0.098
# epoch:1 | 0.116 - 0.316
# epoch:2 | 0.117 - 0.594
# epoch:3 | 0.116 - 0.635
# epoch:4 | 0.117 - 0.661
# epoch:5 | 0.116 - 0.679
# epoch:6 | 0.116 - 0.659
# epoch:7 | 0.116 - 0.683
# epoch:8 | 0.116 - 0.579
# epoch:9 | 0.116 - 0.667
# epoch:10 | 0.117 - 0.671
# epoch:11 | 0.116 - 0.689
# epoch:12 | 0.116 - 0.694
# epoch:13 | 0.117 - 0.7
# epoch:14 | 0.117 - 0.697
# epoch:15 | 0.117 - 0.708
# epoch:16 | 0.117 - 0.778
# epoch:17 | 0.117 - 0.808
# epoch:18 | 0.117 - 0.766
# epoch:19 | 0.117 - 0.804
# No handles with labels found to put in legend.
# ============== 14/16 ==============
# epoch:0 | 0.105 - 0.163
# epoch:1 | 0.116 - 0.343
# epoch:2 | 0.116 - 0.371
# epoch:3 | 0.117 - 0.49
# epoch:4 | 0.116 - 0.501
# epoch:5 | 0.116 - 0.504
# epoch:6 | 0.116 - 0.501
# epoch:7 | 0.116 - 0.51
# epoch:8 | 0.116 - 0.511
# epoch:9 | 0.116 - 0.506
# epoch:10 | 0.116 - 0.519
# epoch:11 | 0.116 - 0.52
# epoch:12 | 0.116 - 0.521
# epoch:13 | 0.116 - 0.521
# epoch:14 | 0.116 - 0.524
# epoch:15 | 0.116 - 0.522
# epoch:16 | 0.116 - 0.525
# epoch:17 | 0.116 - 0.525
# epoch:18 | 0.116 - 0.525
# epoch:19 | 0.116 - 0.525
# No handles with labels found to put in legend.
# ============== 15/16 ==============
# epoch:0 | 0.117 - 0.189
# epoch:1 | 0.116 - 0.21
# epoch:2 | 0.116 - 0.324
# epoch:3 | 0.116 - 0.41
# epoch:4 | 0.116 - 0.4
# epoch:5 | 0.116 - 0.413
# epoch:6 | 0.116 - 0.427
# epoch:7 | 0.117 - 0.409
# epoch:8 | 0.117 - 0.422
# epoch:9 | 0.117 - 0.426
# epoch:10 | 0.117 - 0.429
# epoch:11 | 0.117 - 0.431
# epoch:12 | 0.117 - 0.43
# epoch:13 | 0.116 - 0.418
# epoch:14 | 0.116 - 0.432
# epoch:15 | 0.116 - 0.432
# epoch:16 | 0.116 - 0.434
# epoch:17 | 0.117 - 0.432
# epoch:18 | 0.117 - 0.432
# epoch:19 | 0.117 - 0.433
# No handles with labels found to put in legend.
# ============== 16/16 ==============
# epoch:0 | 0.116 - 0.209
# epoch:1 | 0.116 - 0.117
# epoch:2 | 0.116 - 0.278
# epoch:3 | 0.116 - 0.359
# epoch:4 | 0.116 - 0.373
# epoch:5 | 0.116 - 0.424
# epoch:6 | 0.116 - 0.414
# epoch:7 | 0.116 - 0.425
# epoch:8 | 0.116 - 0.407
# epoch:9 | 0.116 - 0.422
# epoch:10 | 0.116 - 0.428
# epoch:11 | 0.116 - 0.431
# epoch:12 | 0.116 - 0.45
# epoch:13 | 0.116 - 0.426
# epoch:14 | 0.117 - 0.413
# epoch:15 | 0.117 - 0.436
# epoch:16 | 0.117 - 0.426
# epoch:17 | 0.117 - 0.511
# epoch:18 | 0.117 - 0.482
# epoch:19 | 0.117 - 0.473
# <Figure size 640x480 with 16 Axes>
